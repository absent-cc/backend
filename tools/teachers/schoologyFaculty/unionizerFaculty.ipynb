# %%
import csv

from typing import List, Tuple

# %%
faculty_path = 'tools/teachers/schoologyFaculty/NSHS_faculty.csv'
current_path = 'data_backup/NSHS_teachers.csv'

# %%
with open("data/NNHS_faculty.csv", "r") as f:
    data = csv.DictReader(f)
    FACULTY_NAMES: List[Tuple[str, str]] = []
    for col in data:
        FACULTY_NAMES.append((col["First"], col["Last"]))

# %%
with open("data/NNHS_teachers.csv", "r") as f:
    data = csv.DictReader(f)
    TEACHER_NAMES: List[Tuple[str, str]] = []
    for col in data:
        TEACHER_NAMES.append((col["First"], col["Last"]))

# %%
teacher_set = set(TEACHER_NAMES)
faculty_set = set(FACULTY_NAMES)

# %%
difference = faculty_set - teacher_set
print(difference)
# Out:
# {('Richard', 'Cant'), ('Patricia', 'Mason'), ('Roy', ' Dow'), ('Gianna', 'Sarlo'), ('Benjamin', 'Hoadley'), ('Kathryn', 'Lyons'), ('Robert', 'Aufiero'), ('Tim', 'Canty'), ('Maria', 'Camilli'), ('Michael', 'Busani'), ('Chelsea', 'Cedrone'), ('X', 'New Italian Teacher'), ('Grace', 'Baron'), ('James', 'Coughlin'), ('Jon', 'Paul Conopka'), ('Deborah', 'Goldstein'), ('Diksha', 'Pokharel'), ('Jenna', 'Adams'), ('Ethan', 'Hotchkiss'), ('Anna', 'McKeown'), ('Melissa', 'Merullo'), ('Lisa', 'Goldthwaite Wright'), ('Radka', 'Grein'), ('Rachel', 'Ravelli'), ('Michael', 'Salamone'), ('Farah', 'Saeed'), ('Leslie', 'Meyer'), ('Cassidy', 'Donohue'), ('Thomas', 'McNicholas'), ('Corinne', 'Popp'), ('Lisa', 'Langone Berard'), ('Erin', 'Crawford'), ('Kara', 'DiNuccio'), ('David', 'Hawkins'), ('Maelyn', 'Entwistle'), ('Lisa', 'Adil'), ('Pierre-Jean', 'Harrington'), ('Brendan', 'Moran'), ('Chris', 'Murphy'), ('Nicole', 'Franchi'), ('Michael', 'Jackson'), ('Thomas', 'Gwin'), ('Madeleine', 'Odonovan'), ('Ana', 'Mounkary'), ('Elizabeth', 'McKinney'), ('Stephen', 'Lenane'), ('Linda', 'Samuels'), ('Kaitlyn', 'Kelly'), ('Pegeen', 'Kerr'), ('Pamela', 'Pistiner'), ('Jaclyn', 'Goodman'), ('Jonathan', 'Cogswell'), ('Nickole', 'Mitchell'), ('Rebecca', 'Fleming'), ('Debbie', 'Lund'), ('Corey', 'Percival'), ('Sheila', 'Eghbali'), ('Thomas', 'Donnellan'), ('Summer', 'LeCain'), ('Jennifer', "O'Connor"), ('Samantha', 'Chan'), ('Peter', 'Peck'), ('Madeline', 'MacKenzie'), ('Barbara', 'Mole'), ('Daniel', 'Fabrizio'), ('John', 'Reiner'), ('Condro', 'Lukitosari'), ('Bradley', 'Jensen'), ('Ana', 'Rasetti-Pacios'), ('Lisa', 'Mazzola'), ('Michael', 'Barrington Haber'), ('Gabrielle', 'Cauchon'), ('Grace', 'Nicolazzo'), ('Phong', 'Pham'), ('Tessa', 'Bridge'), ('Kenyetta', 'Neal Akowa'), ('Paul', 'Connolly'), ('Shani', 'Leichter'), ('X', 'New Sped Teacher 2'), ('John', 'Callahan'), ('Rhys', 'McGovern'), ('Steven', 'Johnson'), ('Mary', 'DeCourcey'), ('Justin', 'Demers'), ('Lauren', 'Gamel'), ('Marlene', 'Krutter'), ('Mary', 'Dine'), ('Emilio', 'Mazzola'), ('Patricia', 'Leone'), ('Brittaney', 'Courier'), ('Sydney', 'Balise'), ('Sarah', 'Lavalle'), ('Star', 'Lew'), ('Marcy', 'Kammer'), ('Melissa', '(NNHS Bio teacher) Rice'), ('Eric', 'Pfeifer'), ('Dana', 'Jones'), ('Maureen', 'Pursley'), ('Vicki', 'McGovern'), ('Meira', 'Kruskal'), ('Stephanie', 'Mamis'), ('x', 'New Spanish Teacher'), ('Mikaela', 'Flynn'), ('Peter', 'Hatch'), ('Sharon', 'Engler'), ('Courtney', 'Albert Baugher'), ('Larry', 'Allen'), ('Devin', 'Cummings'), ('Kayla', 'Brissett'), ('Alexander', 'Rikleen'), ('Audrey', 'Prager'), ('Alexander', 'Lelchook'), ('Sean', 'Cooper'), ('Laurie', 'Jackson Grusby'), ('David', 'Andrews'), ('Nicholas', 'Grant'), ('Sara', "O'Brien"), ('Christian', 'Collins'), ('Elizabeth', 'Aitoro'), ('Jodie', 'Cohen'), ('Dillon', 'Longmoore'), ('Juanita', 'ONeill'), ('Michael', 'Hazeltine'), ('Michelle', 'Coughlin'), ('Whitney', 'Leonard'), ('Ann', 'Dannenberg'), ('Kristen', 'Rennie'), ('Rilie', 'Brown'), ('Linda', 'Marple'), ('Jonathan', 'Bassett'), ('Julie', 'Athanasiadis'), ('Keren', 'Sammett'), ('Jane', 'Crapulli'), ('William', 'Carter'), ('X', 'New Sped Teacher 1'), ('Nicole', 'Murphy'), ('Kyle', 'Greenidge'), ('Edward', 'Ellis'), ('Timothy', 'Lesinski'), ('Alma', 'Notaro'), ('Jennifer', 'Collins'), ('Helen', 'Day'), ('William', 'McAndrews'), ('Amanda', 'Mortelette'), ('Michael', 'Coppola'), ('Jill', 'Glashow'), ('Deborah', 'Knisell'), ('Adele', 'Poliard'), ('Nicholas', 'Gentile'), ('X', 'New English Teacher 1'), ('X', 'New Science Teacher 1'), ('Profe', 'Alberg'), ('Betherin', 'Busa'), ('Lauren', 'Nufer'), ('Courtney', 'Ross'), ('Adam', 'Cohen'), ('x', 'New Latin Teacher'), ('Adelina', 'Perez Krebs'), ('Jose', 'Sancho'), ('Samantha', 'Davey'), ('James', 'Hall'), ('Rebecca', 'Comiskey'), ('Arthur', 'Kadehjian'), ('Helen', 'Huang-Hobbs'), ('Bonnie', 'Carey'), ('X', 'New Science Teacher 2'), ('Donna', 'Harper'), ('Justin', 'Depamphilis'), ('Adriana', 'Dukakis'), ('Kris', 'Durocher'), ('Joanne ...

# %%
with open('data/NNHS_teachers.csv', "a") as f:
    writer = csv.writer(f)
    for teacher in difference:
        teacher_to_add = list(teacher)
        print(teacher_to_add)
        writer.writerow(teacher_to_add)
# Out:
# ['Richard', 'Cant']
# ['Patricia', 'Mason']
# ['Roy', ' Dow']
# ['Gianna', 'Sarlo']
# ['Benjamin', 'Hoadley']
# ['Kathryn', 'Lyons']
# ['Robert', 'Aufiero']
# ['Tim', 'Canty']
# ['Maria', 'Camilli']
# ['Michael', 'Busani']
# ['Chelsea', 'Cedrone']
# ['X', 'New Italian Teacher']
# ['Grace', 'Baron']
# ['James', 'Coughlin']
# ['Jon', 'Paul Conopka']
# ['Deborah', 'Goldstein']
# ['Diksha', 'Pokharel']
# ['Jenna', 'Adams']
# ['Ethan', 'Hotchkiss']
# ['Anna', 'McKeown']
# ['Melissa', 'Merullo']
# ['Lisa', 'Goldthwaite Wright']
# ['Radka', 'Grein']
# ['Rachel', 'Ravelli']
# ['Michael', 'Salamone']
# ['Farah', 'Saeed']
# ['Leslie', 'Meyer']
# ['Cassidy', 'Donohue']
# ['Thomas', 'McNicholas']
# ['Corinne', 'Popp']
# ['Lisa', 'Langone Berard']
# ['Erin', 'Crawford']
# ['Kara', 'DiNuccio']
# ['David', 'Hawkins']
# ['Maelyn', 'Entwistle']
# ['Lisa', 'Adil']
# ['Pierre-Jean', 'Harrington']
# ['Brendan', 'Moran']
# ['Chris', 'Murphy']
# ['Nicole', 'Franchi']
# ['Michael', 'Jackson']
# ['Thomas', 'Gwin']
# ['Madeleine', 'Odonovan']
# ['Ana', 'Mounkary']
# ['Elizabeth', 'McKinney']
# ['Stephen', 'Lenane']
# ['Linda', 'Samuels']
# ['Kaitlyn', 'Kelly']
# ['Pegeen', 'Kerr']
# ['Pamela', 'Pistiner']
# ['Jaclyn', 'Goodman']
# ['Jonathan', 'Cogswell']
# ['Nickole', 'Mitchell']
# ['Rebecca', 'Fleming']
# ['Debbie', 'Lund']
# ['Corey', 'Percival']
# ['Sheila', 'Eghbali']
# ['Thomas', 'Donnellan']
# ['Summer', 'LeCain']
# ['Jennifer', "O'Connor"]
# ['Samantha', 'Chan']
# ['Peter', 'Peck']
# ['Madeline', 'MacKenzie']
# ['Barbara', 'Mole']
# ['Daniel', 'Fabrizio']
# ['John', 'Reiner']
# ['Condro', 'Lukitosari']
# ['Bradley', 'Jensen']
# ['Ana', 'Rasetti-Pacios']
# ['Lisa', 'Mazzola']
# ['Michael', 'Barrington Haber']
# ['Gabrielle', 'Cauchon']
# ['Grace', 'Nicolazzo']
# ['Phong', 'Pham']
# ['Tessa', 'Bridge']
# ['Kenyetta', 'Neal Akowa']
# ['Paul', 'Connolly']
# ['Shani', 'Leichter']
# ['X', 'New Sped Teacher 2']
# ['John', 'Callahan']
# ['Rhys', 'McGovern']
# ['Steven', 'Johnson']
# ['Mary', 'DeCourcey']
# ['Justin', 'Demers']
# ['Lauren', 'Gamel']
# ['Marlene', 'Krutter']
# ['Mary', 'Dine']
# ['Emilio', 'Mazzola']
# ['Patricia', 'Leone']
# ['Brittaney', 'Courier']
# ['Sydney', 'Balise']
# ['Sarah', 'Lavalle']
# ['Star', 'Lew']
# ['Marcy', 'Kammer']
# ['Melissa', '(NNHS Bio teacher) Rice']
# ['Eric', 'Pfeifer']
# ['Dana', 'Jones']
# ['Maureen', 'Pursley']
# ['Vicki', 'McGovern']
# ['Meira', 'Kruskal']
# ['Stephanie', 'Mamis']
# ['x', 'New Spanish Teacher']
# ['Mikaela', 'Flynn']
# ['Peter', 'Hatch']
# ['Sharon', 'Engler']
# ['Courtney', 'Albert Baugher']
# ['Larry', 'Allen']
# ['Devin', 'Cummings']
# ['Kayla', 'Brissett']
# ['Alexander', 'Rikleen']
# ['Audrey', 'Prager']
# ['Alexander', 'Lelchook']
# ['Sean', 'Cooper']
# ['Laurie', 'Jackson Grusby']
# ['David', 'Andrews']
# ['Nicholas', 'Grant']
# ['Sara', "O'Brien"]
# ['Christian', 'Collins']
# ['Elizabeth', 'Aitoro']
# ['Jodie', 'Cohen']
# ['Dillon', 'Longmoore']
# ['Juanita', 'ONeill']
# ['Michael', 'Hazeltine']
# ['Michelle', 'Coughlin']
# ['Whitney', 'Leonard']
# ['Ann', 'Dannenberg']
# ['Kristen', 'Rennie']
# ['Rilie', 'Brown']
# ['Linda', 'Marple']
# ['Jonathan', 'Bassett']
# ['Julie', 'Athanasiadis']
# ['Keren', 'Sammett']
# ['Jane', 'Crapulli']
# ['William', 'Carter']
# ['X', 'New Sped Teacher 1']
# ['Nicole', 'Murphy']
# ['Kyle', 'Greenidge']
# ['Edward', 'Ellis']
# ['Timothy', 'Lesinski']
# ['Alma', 'Notaro']
# ['Jennifer', 'Collins']
# ['Helen', 'Day']
# ['William', 'McAndrews']
# ['Amanda', 'Mortelette']
# ['Michael', 'Coppola']
# ['Jill', 'Glashow']
# ['Deborah', 'Knisell']
# ['Adele', 'Poliard']
# ['Nicholas', 'Gentile']
# ['X', 'New English Teacher 1']
# ['X', 'New Science Teacher 1']
# ['Profe', 'Alberg']
# ['Betherin', 'Busa']
# ['Lauren', 'Nufer']
# ['Courtney', 'Ross']
# ['Adam', 'Cohen']
# ['x', 'New Latin Teacher']
# ['Adelina', 'Perez Krebs']
# ['Jose', 'Sancho']
# ['Samantha', 'Davey']
# ['James', 'Hall']
# ['Rebecca', 'Comiskey']
# ['Arthur', 'Kadehjian']
# ['Helen', 'Huang-Hobbs']
# ['Bonnie', 'Carey']
# ['X', 'New Science Teacher 2']
# ['Donna', 'Harper']
# ['Justin', 'Depamphilis']
# ['Adriana', 'Dukakis']
# ['Kris', 'Durocher']
# ['Joanne', 'Lonergan']
# ['Layan', 'Rhazi']
# ['Jennifer', 'Espinal']
# ['Elvin', 'Cardona']
# ['Tatyana', 'Osipenko']
# ['Barry', 'Hershenow']
# ['Patricia', 'Niro']
# ['Souhaib', 'Hamrani']
# ['Michael', 'Schlegelmilch']
# ['Stephanie', 'Octave']
# ['Timothy', 'Murphy']
# ['Katherine', 'Schenck']
# ['Zaria', 'McIntosh']
# ['Alicia', 'Bartosik']
# ['Sharon', 'Marich']
# ['Walter', 'Lyons']
# ['Jeffrey', 'Clark']
# ['Caitlin', 'Orourke']
# ['X', 'New Chinese Teacher 1']
# ['Tiana', 'Jordan']
# ['Christina', 'Campbell']
# ['Jennifer', 'Annis']
# ['Tracy', 'Ryan']
# ['X', 'New Ell Teacher']
# ['Linda', 'Fries']
# ['Carolyn', ' Fertig']
# ['Natalia', 'Ruiz Toro']
# ['Barbara', 'Harrison']
# ['Elly', 'Park']
# ['Rucellie', 'Jimenez']
# ['Michael', 'Cadman']
# ['Susan', 'Cohen']
# ['Philip', 'Golando']
# ['Mr.', 'Jackson']
# ['Gabrielle', 'Reisz']
# ['Karissa', 'Kacoyanis']
# ['Kevin', 'ONeil']
# ['Sheela', 'Maupin']
# ['Taylor', 'Lee']
# ['Dani', 'Johnson']
# ['Mary', 'McManus']
# ['Kenneth', 'Artigues']
# ['Patrick', 'Coughlin']
# ['Laura', 'Levin']
# ['Kara', 'Santa Maria']
# ['Isabel', 'Kennedy']
# ['Marc', 'Firenze']
# ['Tricia', 'Lochiatto']
# ['Pablo', 'Casas']
# ['Chaiyanne', 'Monteiro-Dobson']
# ['Jeffrey', 'Pilcher']
# ['Helen', 'McNamee']
# ['Melissa', 'Levin']
# ['Nancy', 'Batt']
# ['Suzanne', 'Heiderich Putzeys']
# ['Aaron', 'Sanders']
# ['Mohammad', 'Hachem (Moe)']
# ['Scott', 'Giusti']
# ['Kathy', 'Lopes']
# ['Tyson', 'Bailey']
# ['Ellen', 'Novinsky']
# ['Lisa', 'Reed']
# ['Lindsay', 'Pearlstein']
# ['Johanna', 'Lynch']
# ['Michelle', 'Lapointe']
# ['X', 'New English Teacher 2']
# ['Timothy', 'Finnegan']
# ['Brenda', 'Loebel April']
# ['Cameron', 'Schiller']
# ['Kathleen', 'Martenis']
# ['Aleks', 'Rodas']
# ['Bradley', 'Mayer']
# ['Erin', 'Haggerty']
# ['Alexander', 'Frail']
# ['Xingyu', 'Meng']
# ['Adriana', 'Bauza']
# ['Jane', 'Kenslea']
# ['Matt', '(NNHS Science) Anderson']
# ['Dan', 'Herman']
# ['Kevin', "O'Brien"]
# ['Lizabeth', 'Mansfield']
# ['Gabriella', 'Cardozo']
# ['Courtney', 'Leahy']
# ['Patricia', 'Bohling']
# ['Brian', 'Redmond']
# ['Jason', 'Bonneau']
# ['Steven', 'Gianquitti']
# ['Monika', 'Manocha']
# ['Dave', 'Bennett']
# ['Carolyn', 'Camerato']
# ['Shu', 'Yee Freake']
# ['Debbie', 'Donovan']
# ['Tom', 'Giusti']
# ['Barbara', 'Gibson']
# ['Ali', 'Newton']
# ['Sara', 'Foley']
# ['Peter', 'Barry']
# ['Shea', 'Matta']
# ['Deborah', 'Dessner De Jose']
# ['Li', 'Jia']
# ['David', 'Meshoulam']
# ['Rafael', 'Martinez']
# ['Bess', "O'Neil"]
# ['Aileen', 'Donohue']
# ['Kate', 'McCarthy']
# ['Lillian', 'Duest']
# ['Kirsten', 'McCarthy']
# ['Mary', 'Queisser']
# ['Stephen', 'Hess']
# ['Meghan', 'Murtagh']
# ['Nicole', 'Leggeri']
# ['Kyle', 'Gotham']
# ['David', 'Albert']
# ['Nicole', 'Conway']
# ['Mackenzie', 'Cutler']
# ['Nash', 'Petrovic']
# ['Elizabeth', "O'Brien"]
# ['Jacqueline', 'Menton']
# ['x', 'New Bio Teacher']
# ['Lexi', 'Brown']
# ['Eric', 'Lochiatto']
# ['Brian', 'Padilla']
# ['Frances', 'Davis']
# ['Señora', 'Rojas Rojas']
# ['Erin', 'Mclaughlin']
# ['Alexander', 'Laser']
# ['Antonette', 'Perri']
# ['Dobbin', 'Bookman']
# ['Heather', 'Irber']
# ['Eliza', 'Lewis']
# ['Kimberly', 'Hamilton']
# ['Leigh', 'Haywood']
# ['Andrew', 'Fusco']
# ['Sarah', 'Maxwell']
# ['Matthew', 'Kelly']

# %%
with open("data/NNHS_teachers.csv", "r") as f:
    data = csv.DictReader(f)
    NEW_TEACHERS: List[Tuple[str, str]] = []
    for col in data:
        NEW_TEACHERS.append((col["First"], col["Last"]))

# %%
sorted_new_teachers = sorted(NEW_TEACHERS)

# %%
print(sorted_new_teachers)
# Out:
# [('Aaron', 'Sanders'), ('Aaron', 'Sanders, Jr.'), ('Adam', 'Brown'), ('Adam', 'Cohen'), ('Adam', 'George'), ('Adam', 'Grossman'), ('Adam', 'Peloquin'), ('Adele', 'Poliard'), ('Adelina', 'Perez Krebs'), ('Adriana', 'Bauza'), ('Adriana', 'Dukakis'), ('Aileen', 'Donohue'), ('Albert', 'Calderone'), ('Albert', 'Cho'), ('Aleks', 'Rodas'), ('Alexander', 'Frail'), ('Alexander', 'Laser'), ('Alexander', 'Lelchook'), ('Alexander', 'Rikleen'), ('Alexis', 'Lugbauer'), ('Ali', 'Newton'), ('Alicia', 'Bartosik'), ('Alicia', 'Carrillo'), ('Alieu', 'Jobe'), ('Alison', 'Malkin'), ('Allegra', 'Atkinson'), ('Allison', 'Newton'), ('Alma', 'Notaro'), ('Amanda', 'Choi'), ('Amanda', 'Griffin'), ('Amanda', 'Mazzola'), ('Amanda', 'Mortelette'), ('Amelia', 'May'), ('Amie', 'Harris'), ('Amy', 'Donovan'), ('Amy', 'Heslin'), ('Amy', 'McMahon'), ('Amy', 'Winston'), ('Amy', 'Worth'), ('Ana', 'Mounkary'), ('Ana', 'Rasetti-Pacios'), ('Ana', 'Tellado-Schiff'), ('Andrea', 'Koenig'), ('Andrea', 'Shurtleff'), ('Andrew', 'Fusco'), ('Andrew', 'Spear'), ('Andrew', 'Ziomek'), ('Ann', 'Dannenberg'), ('Anna', 'George'), ('Anna', 'Hill'), ('Anna', 'McKeown'), ('Anna', 'Sanford'), ('Anthony', 'Patelis'), ('Antonette', 'Perri'), ('Arielle', 'Miles'), ('Arthur', 'Kadehjian'), ('Atiera', 'Horne'), ('Audrey', 'Prager'), ('Barbara', 'Gibson'), ('Barbara', 'Harrison'), ('Barbara', 'Johnson'), ('Barbara', 'Mole'), ('Barry', 'Hershenow'), ('Belma', 'Johnson'), ('Ben', 'Hoadley'), ('Benjamin', 'Hoadley'), ('Bess', "O'Neil"), ('Beth', 'Busa'), ('Beth', 'Cronin'), ('Beth', "O'Brien"), ('Beth', 'Swederskas'), ('Betherin', 'Busa'), ('Bill', 'McAndrews'), ('Bonnie', 'Carey'), ('Bradley', 'Jensen'), ('Bradley', 'Mayer'), ('Brandon', 'Mogayzel'), ('Brenda', 'Loebel April'), ('Brendan', 'Amedio'), ('Brendan', 'Moran'), ('Brian', 'Gagne'), ('Brian', 'Goeselt'), ('Brian', 'Padilla'), ('Brian', 'Reardon'), ('Brian', 'Redmond'), ('Brian', 'Rooney'), ('Brittaney', 'Courier'), ('Caitlin', "O'Rourke"), ('Caitlin', 'Orourke'), ('Cameron', 'Schiller'), ('Carol', 'Ouellette'), ('Caroline', 'Vuilleumier'), ('Carolyn', ' Fertig'), ('Carolyn', 'Camerato'), ('Carolyn', 'Fertig'), ('Carrie', 'Bates'), ('Casey', 'Friend'), ('Cassidy', 'Donahue'), ('Cassidy', 'Donohue'), ('Chaiyanne', 'Monteiro-Dobson'), ('Charlene', 'Beh'), ('Charles', 'Rooney'), ('Chelsea', 'Cedrone'), ('Cheryl', 'Etoniru'), ('Cheryl', 'Stover'), ('Chris', 'Alberg'), ('Chris', 'Murphy'), ('Chris', 'Wood'), ('Christian', 'Collins'), ('Christina', 'Campbell'), ('Christina', 'Mazzeo'), ('Christine', 'Choate'), ('Christine', 'Potter'), ('Christopher', 'Hillenmeyer'), ('Cindy', 'Massoff'), ('Claudia', 'Carmody'), ('Claudia', 'Wu'), ('Colleen', 'Crowley'), ('Colleen', 'Meigher'), ('Colleen', 'Moore'), ('Condro', 'Lukitosari'), ('Corey', 'Percival'), ('Corinne', 'Popp'), ('Cortnie', 'Daly'), ('Courtney', 'Albert'), ('Courtney', 'Albert Baugher'), ('Courtney', 'Dunne'), ('Courtney', 'Leahy'), ('Courtney', 'Ross'), ('Cristina', 'Schulze'), ('Dan', 'Fabrizio'), ('Dan', 'Herman'), ('Dana', 'Jones'), ('Dana', 'Shulsinger'), ('Dani', 'Johnson'), ('Daniel', 'Fabrizio'), ('Danielle', 'Johnson'), ('Dave', 'Bennett'), ('David', 'Albert'), ('David', 'Andrews'), ('David', 'Bedar'), ('David', 'Bennett'), ('David', 'Hawkins'), ('David', 'Jackson, Jr.'), ('David', 'Meshoulam'), ('Deb', 'Jose'), ('Debbie', 'Donovan'), ('Debbie', 'Knisell'), ('Debbie', 'Lund'), ('Deborah', 'Dessner De Jose'), ('Deborah', 'Goldstein'), ('Deborah', 'Jose'), ('Deborah', 'Knisell'), ('Denise', 'Cremin'), ('Dennis', 'Klem'), ('Derek', 'Hogan'), ('Derek', 'Knapp'), ('Devin', 'Cummings'), ('Dianne', 'Lochhead'), ('Diksha', 'Pokharel'), ('Dillon', 'Longmoore'), ('Dobbin', 'Bookman'), ('Donna', 'Benoit'), ('Donna', 'Harper'), ('Duncan', 'Wood'), ('Dwayne', 'Melcher'), ('Edward', 'Ellis'), ('Eileen', 'Gagarin'), ('Eileen', 'Perruzzi'), ('Elisse', 'Ghitelman'), ('Eliza', 'Lewis'), ('Elizabeth', 'Aitoro'), ('Elizabeth', 'Carlson'), ('Elizabeth', 'Hobbs'), ('Elizabeth', 'James'), ('Elizabet ...

# %%
with open('data/NNHS_teachers_final.csv', "w+") as f:
    writer = csv.writer(f)
    for teacher in sorted_new_teachers:
        teacher_to_add = list(teacher)
        print(teacher_to_add)
        writer.writerow(teacher_to_add)
# Out:
# ['Aaron', 'Sanders']
# ['Aaron', 'Sanders, Jr.']
# ['Adam', 'Brown']
# ['Adam', 'Cohen']
# ['Adam', 'George']
# ['Adam', 'Grossman']
# ['Adam', 'Peloquin']
# ['Adele', 'Poliard']
# ['Adelina', 'Perez Krebs']
# ['Adriana', 'Bauza']
# ['Adriana', 'Dukakis']
# ['Aileen', 'Donohue']
# ['Albert', 'Calderone']
# ['Albert', 'Cho']
# ['Aleks', 'Rodas']
# ['Alexander', 'Frail']
# ['Alexander', 'Laser']
# ['Alexander', 'Lelchook']
# ['Alexander', 'Rikleen']
# ['Alexis', 'Lugbauer']
# ['Ali', 'Newton']
# ['Alicia', 'Bartosik']
# ['Alicia', 'Carrillo']
# ['Alieu', 'Jobe']
# ['Alison', 'Malkin']
# ['Allegra', 'Atkinson']
# ['Allison', 'Newton']
# ['Alma', 'Notaro']
# ['Amanda', 'Choi']
# ['Amanda', 'Griffin']
# ['Amanda', 'Mazzola']
# ['Amanda', 'Mortelette']
# ['Amelia', 'May']
# ['Amie', 'Harris']
# ['Amy', 'Donovan']
# ['Amy', 'Heslin']
# ['Amy', 'McMahon']
# ['Amy', 'Winston']
# ['Amy', 'Worth']
# ['Ana', 'Mounkary']
# ['Ana', 'Rasetti-Pacios']
# ['Ana', 'Tellado-Schiff']
# ['Andrea', 'Koenig']
# ['Andrea', 'Shurtleff']
# ['Andrew', 'Fusco']
# ['Andrew', 'Spear']
# ['Andrew', 'Ziomek']
# ['Ann', 'Dannenberg']
# ['Anna', 'George']
# ['Anna', 'Hill']
# ['Anna', 'McKeown']
# ['Anna', 'Sanford']
# ['Anthony', 'Patelis']
# ['Antonette', 'Perri']
# ['Arielle', 'Miles']
# ['Arthur', 'Kadehjian']
# ['Atiera', 'Horne']
# ['Audrey', 'Prager']
# ['Barbara', 'Gibson']
# ['Barbara', 'Harrison']
# ['Barbara', 'Johnson']
# ['Barbara', 'Mole']
# ['Barry', 'Hershenow']
# ['Belma', 'Johnson']
# ['Ben', 'Hoadley']
# ['Benjamin', 'Hoadley']
# ['Bess', "O'Neil"]
# ['Beth', 'Busa']
# ['Beth', 'Cronin']
# ['Beth', "O'Brien"]
# ['Beth', 'Swederskas']
# ['Betherin', 'Busa']
# ['Bill', 'McAndrews']
# ['Bonnie', 'Carey']
# ['Bradley', 'Jensen']
# ['Bradley', 'Mayer']
# ['Brandon', 'Mogayzel']
# ['Brenda', 'Loebel April']
# ['Brendan', 'Amedio']
# ['Brendan', 'Moran']
# ['Brian', 'Gagne']
# ['Brian', 'Goeselt']
# ['Brian', 'Padilla']
# ['Brian', 'Reardon']
# ['Brian', 'Redmond']
# ['Brian', 'Rooney']
# ['Brittaney', 'Courier']
# ['Caitlin', "O'Rourke"]
# ['Caitlin', 'Orourke']
# ['Cameron', 'Schiller']
# ['Carol', 'Ouellette']
# ['Caroline', 'Vuilleumier']
# ['Carolyn', ' Fertig']
# ['Carolyn', 'Camerato']
# ['Carolyn', 'Fertig']
# ['Carrie', 'Bates']
# ['Casey', 'Friend']
# ['Cassidy', 'Donahue']
# ['Cassidy', 'Donohue']
# ['Chaiyanne', 'Monteiro-Dobson']
# ['Charlene', 'Beh']
# ['Charles', 'Rooney']
# ['Chelsea', 'Cedrone']
# ['Cheryl', 'Etoniru']
# ['Cheryl', 'Stover']
# ['Chris', 'Alberg']
# ['Chris', 'Murphy']
# ['Chris', 'Wood']
# ['Christian', 'Collins']
# ['Christina', 'Campbell']
# ['Christina', 'Mazzeo']
# ['Christine', 'Choate']
# ['Christine', 'Potter']
# ['Christopher', 'Hillenmeyer']
# ['Cindy', 'Massoff']
# ['Claudia', 'Carmody']
# ['Claudia', 'Wu']
# ['Colleen', 'Crowley']
# ['Colleen', 'Meigher']
# ['Colleen', 'Moore']
# ['Condro', 'Lukitosari']
# ['Corey', 'Percival']
# ['Corinne', 'Popp']
# ['Cortnie', 'Daly']
# ['Courtney', 'Albert']
# ['Courtney', 'Albert Baugher']
# ['Courtney', 'Dunne']
# ['Courtney', 'Leahy']
# ['Courtney', 'Ross']
# ['Cristina', 'Schulze']
# ['Dan', 'Fabrizio']
# ['Dan', 'Herman']
# ['Dana', 'Jones']
# ['Dana', 'Shulsinger']
# ['Dani', 'Johnson']
# ['Daniel', 'Fabrizio']
# ['Danielle', 'Johnson']
# ['Dave', 'Bennett']
# ['David', 'Albert']
# ['David', 'Andrews']
# ['David', 'Bedar']
# ['David', 'Bennett']
# ['David', 'Hawkins']
# ['David', 'Jackson, Jr.']
# ['David', 'Meshoulam']
# ['Deb', 'Jose']
# ['Debbie', 'Donovan']
# ['Debbie', 'Knisell']
# ['Debbie', 'Lund']
# ['Deborah', 'Dessner De Jose']
# ['Deborah', 'Goldstein']
# ['Deborah', 'Jose']
# ['Deborah', 'Knisell']
# ['Denise', 'Cremin']
# ['Dennis', 'Klem']
# ['Derek', 'Hogan']
# ['Derek', 'Knapp']
# ['Devin', 'Cummings']
# ['Dianne', 'Lochhead']
# ['Diksha', 'Pokharel']
# ['Dillon', 'Longmoore']
# ['Dobbin', 'Bookman']
# ['Donna', 'Benoit']
# ['Donna', 'Harper']
# ['Duncan', 'Wood']
# ['Dwayne', 'Melcher']
# ['Edward', 'Ellis']
# ['Eileen', 'Gagarin']
# ['Eileen', 'Perruzzi']
# ['Elisse', 'Ghitelman']
# ['Eliza', 'Lewis']
# ['Elizabeth', 'Aitoro']
# ['Elizabeth', 'Carlson']
# ['Elizabeth', 'Hobbs']
# ['Elizabeth', 'James']
# ['Elizabeth', 'McKinney']
# ['Elizabeth', "O'Brien"]
# ['Ellen', 'Novinsky']
# ['Elly', 'Park']
# ['Elvin', 'Cardona']
# ['Emilio', 'Mazzola']
# ['Emily', 'Bozeman']
# ['Emily', 'Lew']
# ['Emily', 'Lewis']
# ['Emma', 'Lichtenstein']
# ['Eric', 'Lochiatto']
# ['Eric', 'Pfeifer']
# ['Erin', 'Crawford']
# ['Erin', 'Dalbec']
# ['Erin', 'Haggerty']
# ['Erin', 'Mclaughlin']
# ['Ethan', 'Hotchkiss']
# ['Ethan', 'Peritz']
# ['FIRST', 'LAST']
# ['Farah', 'Saeed']
# ['First Name', 'Last Name']
# ['Frances', 'Davis']
# ['Gabriella', 'Cardozo']
# ['Gabrielle', 'Cauchon']
# ['Gabrielle', 'Reisz']
# ['Garrett', 'Tingle']
# ['Germana', 'Santelli']
# ['Gianna', 'Sarlo']
# ['Grace', 'Baron']
# ['Grace', 'Nicolazzo']
# ['Gregory', 'Drake']
# ['Heather', 'Gilbert']
# ['Heather', 'Gilbert']
# ['Heather', 'Haines']
# ['Heather', 'Hotchkiss']
# ['Heather', 'Irber']
# ['Heather', 'Wood']
# ['Heidi', 'Bochain']
# ['Helen', 'Day']
# ['Helen', 'Huang-Hobbs']
# ['Helen', 'McNamee']
# ['Helen', 'Wong']
# ['Henry', 'Turner']
# ['Holly', 'St. Peter']
# ['Isabel', 'Kennedy']
# ['Isabelle', 'Ronfard']
# ['Isongesit', 'Ibokette']
# ['Jaclyn', 'Goodman']
# ['Jacqueline', 'Menton']
# ['James', 'Coughlin']
# ['James', 'Hall']
# ['Jamie', 'Bal']
# ['Jamie', 'Moore']
# ['Jane', 'Crapulli']
# ['Jane', 'Kenslea']
# ['Janice', 'Miller']
# ['Jason', 'Bonneau']
# ['Jay', 'Zawacki']
# ['Jeffrey', 'Clark']
# ['Jeffrey', 'Pilcher']
# ['Jenn', 'Pontillo']
# ['Jenna', 'Adams']
# ['Jenna', 'Lashley']
# ['Jenni', 'Morreale']
# ['Jennifer', 'Annis']
# ['Jennifer', 'Collins']
# ['Jennifer', 'Devlin']
# ['Jennifer', 'Espinal']
# ['Jennifer', 'Geraghty']
# ['Jennifer', 'Letourneau']
# ['Jennifer', "O'Connor"]
# ['Jessica', 'Steel']
# ['Jessica', 'Volmer']
# ['Jill', 'Curry']
# ['Jill', 'Glashow']
# ['Jillian', 'Hall']
# ['Joanna', 'Gualtieri']
# ['Joanne', 'Lonergan']
# ['Jodie', 'Cohen']
# ['Joe', 'Cahill']
# ['Johanna', 'Lynch']
# ['John', 'Callahan']
# ['John', 'Fitzgerald']
# ['John', 'McNamara']
# ['John', 'Reiner']
# ['Jolleen', 'Filio']
# ['Jon', 'Paul Conopka']
# ['Jonathan', 'Bassett']
# ['Jonathan', 'Cogswell']
# ['Jose', 'Sancho']
# ['José Luis', 'Sancho']
# ['Juanita', 'ONeill']
# ['Julie', 'Athanasiadis']
# ['Justin', 'Demers']
# ['Justin', 'Depamphilis']
# ['Justin', 'Evans']
# ['Kaitlyn', 'Kelly']
# ['Kanchan', 'Kant']
# ['Kara', 'DiNuccio']
# ['Kara', 'Santa Maria']
# ['Karen', 'Tokos']
# ['Karissa', 'Kacoyanis']
# ['Kate', 'Kennedy']
# ['Kate', 'Mannelly']
# ['Kate', 'McCarthy']
# ['Kate', 'Shaughnessy']
# ['Kate', 'Woodford']
# ['Katherine', 'Schenck']
# ['Kathleen', 'Duff']
# ['Kathleen', 'Martenis']
# ['Kathryn', 'Codd']
# ['Kathryn', 'Lyons']
# ['Kathryn', 'Teissier du Cros']
# ['Kathy', 'Lopes']
# ['Katie', 'Cacace']
# ['Katie', 'Collins']
# ['Katie', 'Connolly']
# ['Kayla', 'Brissett']
# ['Keith', 'Whelan']
# ['Kenneth', 'Artigues']
# ['Kenyetta', 'Neal Akowa']
# ['Keren', 'Sammett']
# ['Kevin', 'Brosnan']
# ['Kevin', "O'Brien"]
# ['Kevin', 'ONeil']
# ['Khari', 'Roulhac']
# ['Kim', 'Mayer']
# ['Kimberly', 'Hamilton']
# ['Kirsten', 'McCarthy']
# ['Kris', 'Durocher']
# ['Kristen', 'Durocher']
# ['Kristen', 'Rennie']
# ['Kristen', 'Smith']
# ['Krystal', 'Powers']
# ['Kyle', 'Gotham']
# ['Kyle', 'Greenidge']
# ['Kyra', 'Slawski']
# ['Larry', 'Allen']
# ['Laura', 'DiMascio']
# ['Laura', 'Levin']
# ['Laura', 'Schertzer']
# ['Lauren', 'Baugher']
# ['Lauren', 'Gamel']
# ['Lauren', 'Italiano']
# ['Lauren', 'Nufer']
# ['Laurie', 'Jackson Grusby']
# ['Laurie', 'Paul']
# ['Layan', 'Rhazi']
# ['Leah', 'Castellano']
# ['Leah', 'Doyle']
# ['Leigh', 'Haywood']
# ['Leigh', 'Paris']
# ['Leslie', 'Kepner']
# ['Leslie', 'Meyer']
# ['Lexi', 'Brown']
# ['Li', 'Jia']
# ['Liana', 'Kish']
# ['Lila', 'Reid']
# ['Lillian', 'Duest']
# ['Linda', 'Fries']
# ['Linda', 'Marple']
# ['Linda', 'Samuels']
# ['Lindsay', 'Pearlstein']
# ['Lisa', 'Adil']
# ['Lisa', 'Goldthwaite']
# ['Lisa', 'Goldthwaite Wright']
# ['Lisa', 'Langone Berard']
# ['Lisa', 'Marzilli']
# ['Lisa', 'Mazzola']
# ['Lisa', 'McKinney']
# ['Lisa', 'Reed']
# ['Liz', 'Mansfield']
# ['Lizabeth', 'Mansfield']
# ['Lory', 'Dix']
# ['Lynne', 'Ruozzi']
# ['Mackenzie', 'Cutler']
# ['Madeleine', "O'Donovan"]
# ['Madeleine', 'Odonovan']
# ['Madeline', 'MacKenzie']
# ['Maelyn', 'Entwistle']
# ['Maggie', 'McCullar']
# ['Marc', 'Firenze']
# ['Marcy', 'Kammer']
# ['Maria', 'Camilli']
# ['Maria', 'Hegarty']
# ['Mark', 'Lutz']
# ['Mark', 'Panichella']
# ['Marla', 'Glaskin']
# ['Marlene', 'Krutter']
# ['Mary', 'DeCourcey']
# ['Mary', 'Dine']
# ['Mary', 'McManus']
# ['Mary', 'Queisser']
# ['Mary', 'Vallo']
# ['Mary-Ellen', 'Hurd']
# ['Matt', '(NNHS Science) Anderson']
# ['Matt', 'Anderson']
# ['Matthew', 'Espelin']
# ['Matthew', 'Ford']
# ['Matthew', 'Kelly']
# ['Maureen', 'Kavanaugh']
# ['Maureen', 'Pursley']
# ['Max', 'Roberts']
# ['Megan', 'Sun']
# ['Meghan', 'Burns']
# ['Meghan', 'Murtagh']
# ['Meira', 'Kruskal']
# ['Melanie', 'Pennison']
# ['Melissa', '(NNHS Bio teacher) Rice']
# ['Melissa', 'Dilworth']
# ['Melissa', 'Hanenberger']
# ['Melissa', 'Levin']
# ['Melissa', 'Merullo']
# ['Melissa', 'Perez']
# ['Melissa', 'Phair']
# ['Melynda', 'Meszko-Cameron']
# ['Mercy', 'Adoma Fosu']
# ['Michael', 'Barrington Haber']
# ['Michael', 'Barrington-Haber']
# ['Michael', 'Bono']
# ['Michael', 'Bower']
# ['Michael', 'Busani']
# ['Michael', 'Cadman']
# ['Michael', 'Coppola']
# ['Michael', 'Fieleke']
# ['Michael', 'Hazeltine']
# ['Michael', 'Jackson']
# ['Michael', 'Salamone']
# ['Michael', 'Schlegelmilch']
# ['Michele', 'Kennedy']
# ['Michele', 'Leong']
# ['Michele', 'Widener']
# ['Michelle', 'Coughlin']
# ['Michelle', 'Lapointe']
# ['Michelle', 'Ramsdell']
# ['Michelle', 'Schofield']
# ['Michelle', 'Stauss']
# ['Mikaela', 'Flynn']
# ['Mike', 'Schlegelmilch']
# ['Ming', 'Lu']
# ['Mohammad', 'Hachem (Moe)']
# ['Monika', 'Manocha']
# ['Mr.', 'Jackson']
# ['Nancy', 'Batt']
# ['Nancy', 'Decoteau']
# ['Nancy', 'Marrinucci']
# ['Naomi', 'Berg']
# ['Nash', 'Petrovic']
# ['Natalia', 'Ruiz Toro']
# ['Neil', 'Giordano']
# ['Nicholas', 'Capodilupo']
# ['Nicholas', 'Gentile']
# ['Nicholas', 'Grant']
# ['Nick', 'Pfeifer']
# ['Nickole', 'Mitchell']
# ['Nicky', 'Franchi']
# ['Nicolas', 'Gargaro']
# ['Nicole', 'Conway']
# ['Nicole', 'Franchi']
# ['Nicole', 'Leggeri']
# ['Nicole', 'Murphy']
# ['Nicole', 'Randall']
# ['Nina', 'Cedrone']
# ['Nora', 'Lord']
# ['Pablo', 'Casas']
# ['Pam', 'Pistiner']
# ['Pamela', 'Pistiner']
# ['Patricia', 'Bohling']
# ['Patricia', 'Leone']
# ['Patricia', 'Mason']
# ['Patricia', 'Niro']
# ['Patricia', 'Stamper']
# ['Patrick', 'Coughlin']
# ['Patrick', 'Manning']
# ['Paul', 'Connolly']
# ['Paul', 'Martenis']
# ['Pegeen', 'Kerr']
# ['Peter', 'Barry']
# ['Peter', 'Cavanagh']
# ['Peter', 'Goddard']
# ['Peter', 'Hamel']
# ['Peter', 'Hamel']
# ['Peter', 'Hatch']
# ['Peter', 'Peck']
# ['Peter', 'Turner']
# ['Phil', 'Golando']
# ['Philip', 'Golando']
# ['Phong', 'Pham']
# ['Pierre-Jean', 'Harrington']
# ['Profe', 'Alberg']
# ['Rachel', 'Mingos']
# ['Rachel', 'Ravelli']
# ['Radka', 'Grein']
# ['Rafael', 'Martinez']
# ['Rebecca', 'Comiskey']
# ['Rebecca', 'Fleming']
# ['Rhys', 'McGovern']
# ['Richard', 'Cant']
# ['Richard', 'Labedz']
# ['Rick', 'Michalka']
# ['Riley', 'Brown']
# ['Rilie', 'Brown']
# ['Rob', 'Greenfield']
# ['Rob', 'Kane']
# ['Robert', 'Aufiero']
# ['Robert', 'MacDougall']
# ['Roy', ' Dow']
# ['Rucellie', 'Jimenez']
# ['Ruth', 'Talvacchia']
# ['Samantha', 'Chan']
# ['Samantha', 'Davey']
# ['Samantha', 'Petracca']
# ['Samuel', 'Shoutis']
# ['Sangeet', 'Srikanth']
# ['Sara', 'Foley']
# ['Sara', 'McKechnie']
# ['Sara', "O'Brien"]
# ['Sara', 'Polstein']
# ['Sarah', 'Bilodeau']
# ['Sarah', 'Kerdok']
# ['Sarah', 'Lavalle']
# ['Sarah', 'Maxwell']
# ['Scot', 'MacMannis']
# ['Scott', 'Dunlop']
# ['Scott', 'Giusti']
# ['Scott', 'Heslin']
# ['Scott', 'Rosenhahn']
# ['Sean', 'Cooper']
# ['Selena', 'Giroux']
# ['Señora', 'Rojas Rojas']
# ['Shani', 'Leichter']
# ['Shaniece', 'Rojas']
# ['Shannon', 'Slattery']
# ['Sharon', 'Engler']
# ['Sharon', 'Marich']
# ['Shawn', 'Wallace']
# ['Shea', 'Matta']
# ['Sheela', 'Maupin']
# ['Sheila', 'Eghbali']
# ['Sheldon', 'Reid']
# ['Sherri', 'Ziomek']
# ['Shu', 'Yee Freake']
# ['Shu-Yee', 'Chen (Freake)']
# ['Silvia', 'Dupont']
# ['Smitha', 'Sahadevan']
# ['Souhaib', 'Hamrani']
# ['Spencer', 'Marzano']
# ['Star', 'Lew']
# ['Star (Yixing)', 'Lew']
# ['Star (Yixing)', 'Lew']
# ['Stephanie', 'Mamis']
# ['Stephanie', 'Octave']
# ['Stephanie', 'Piantedosi']
# ['Stephen', 'Hess']
# ['Stephen', 'Jamele']
# ['Stephen', 'Lenane']
# ['Stephen', 'Litwack']
# ['Steve', 'Hess']
# ['Steve', 'Johnson']
# ['Steven', 'Gianquitti']
# ['Steven', 'Johnson']
# ['Subheen', 'Razzaqui']
# ['Sue', 'Brooks']
# ['Sumit', 'Majumder']
# ['Summer', 'LeCain']
# ['Susan', 'Carbone']
# ['Susan', 'Cohen']
# ['Susan', 'Mucci']
# ['Suzanne', 'Heiderich Putzeys']
# ['Suzanne', 'Spirito']
# ['Sydney', 'Balise']
# ['Tara', 'Kfoury']
# ['Tatyana', 'Osipenko']
# ['Taylor', 'Lee']
# ['Terry', 'Yoffie']
# ['Tessa', 'Bridge']
# ['Theresa', 'Karloff']
# ['Thomas', 'Barry']
# ['Thomas', 'Donnellan']
# ['Thomas', 'Fabian']
# ['Thomas', 'Gwin']
# ['Thomas', 'MacIntyre']
# ['Thomas', 'McNicholas']
# ['Tiana', 'Jordan']
# ['Tim', 'Canty']
# ['Tim', 'Finnegan']
# ['Tim', 'Lesinski']
# ['Tim', 'Murphy']
# ['Timothy', 'Finnegan']
# ['Timothy', 'Lesinski']
# ['Timothy', 'Murphy']
# ['Todd', 'Young']
# ['Tom', 'Donnellan']
# ['Tom', 'Giusti']
# ['Tom', 'Gwin']
# ['Tracey', 'Mucci']
# ['Tracey', 'Stewart']
# ['Tracy', 'Ryan']
# ['Tricia', 'Lochiatto']
# ['Tuuli', 'McElroy']
# ['Tyson', 'Bailey']
# ['Valerie', 'Young']
# ['Vicki', 'McGovern']
# ['Vu', 'Ha']
# ['Walter', 'Lyons']
# ['Whitney', 'Leonard']
# ['William', 'Carter']
# ['William', 'Joiner']
# ['William', 'McAndrews']
# ['X', 'New Chinese Teacher 1']
# ['X', 'New Ell Teacher']
# ['X', 'New English Teacher 1']
# ['X', 'New English Teacher 2']
# ['X', 'New Italian Teacher']
# ['X', 'New Science Teacher 1']
# ['X', 'New Science Teacher 2']
# ['X', 'New Sped Teacher 1']
# ['X', 'New Sped Teacher 2']
# ['Xingyu', 'Meng']
# ['Yaelle', 'Nisinzweig']
# ['Yen', 'Tieu']
# ['Yuzhe', 'Wang']
# ['Zaria', 'McIntosh']
# ['x', 'New Bio Teacher']
# ['x', 'New Latin Teacher']
# ['x', 'New Spanish Teacher']
